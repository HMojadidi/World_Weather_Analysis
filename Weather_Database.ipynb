# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b07b61a9734ffdb538936c12a27a0b7f

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | salamiyah
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | zhigansk
# Processing Record 4 of Set 1 | verkhoyansk
# Processing Record 5 of Set 1 | viedma
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | ocos
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | kavaratti
# Processing Record 11 of Set 1 | trojes
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | bardsir
# Processing Record 18 of Set 1 | san policarpo
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | shingu
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | belvedere marittimo
# Processing Record 23 of Set 1 | rocha
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | minab
# Processing Record 26 of Set 1 | boulder city
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | santa maria
# Processing Record 32 of Set 1 | pilar do sul
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | bismarck
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | bengkulu
# Processing Record 38 of Set 1 | santo antonio do taua
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | ust-kuyga
# Processing Record 42 of Set 1 | boyolangu
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | nguruka
# Processing Record 45 of Set 1 | mildura
# Processing Record 46 of Set 1 | teeli
# Processing Record 47 of Set 1 | smithers
# Processing Record 48 of Set 1 | alofi
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | atambua
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | salalah
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | san andres
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | port blair
# Processing Record 15 of Set 2 | ballina
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | komsomolskiy
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 2 | panaba
# Processing Record 23 of Set 2 | khorramabad
# Processing Record 24 of Set 2 | taltal
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | queimadas
# Processing Record 29 of Set 2 | san cosme y damian
# Processing Record 30 of Set 2 | kosh-agach
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | maryville
# Processing Record 34 of Set 2 | umm lajj
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | sisimiut
# Processing Record 37 of Set 2 | arman
# Processing Record 38 of Set 2 | asyut
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | arlit
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | pacific grove
# Processing Record 43 of Set 2 | vostok
# Processing Record 44 of Set 2 | lamu
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | lock haven
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | dolgorukovo
# Processing Record 49 of Set 2 | barth
# Processing Record 50 of Set 2 | itumbiara
# Processing Record 1 of Set 3 | rawson
# Processing Record 2 of Set 3 | japaratuba
# Processing Record 3 of Set 3 | cap malheureux
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | kuryk
# Processing Record 7 of Set 3 | vao
# Processing Record 8 of Set 3 | san jeronimo
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | margate
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | vawkavysk
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | oranjestad
# Processing Record 16 of Set 3 | capreol
# Processing Record 17 of Set 3 | petauke
# Processing Record 18 of Set 3 | padang
# Processing Record 19 of Set 3 | saint-georges
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | minuwangoda
# Processing Record 24 of Set 3 | biak
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | muroto
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | simplicio mendes
# Processing Record 29 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | piacabucu
# Processing Record 32 of Set 3 | kraainem
# Processing Record 33 of Set 3 | ambanja
# Processing Record 34 of Set 3 | grenaa
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | safita
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | okhotsk
# Processing Record 39 of Set 3 | kaeo
# Processing Record 40 of Set 3 | kandiari
# Processing Record 41 of Set 3 | inta
# Processing Record 42 of Set 3 | auki
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | cape town
# Processing Record 45 of Set 3 | nemuro
# Processing Record 46 of Set 3 | port macquarie
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | ostrovnoy
# Processing Record 49 of Set 3 | narsaq
# Processing Record 50 of Set 3 | yulara
# Processing Record 1 of Set 4 | det udom
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | bairiki
# Processing Record 4 of Set 4 | hilo
# Processing Record 5 of Set 4 | alice springs
# Processing Record 6 of Set 4 | imbituba
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | sibolga
# Processing Record 12 of Set 4 | buraydah
# Processing Record 13 of Set 4 | mutis
# Processing Record 14 of Set 4 | college
# Processing Record 15 of Set 4 | tromso
# Processing Record 16 of Set 4 | lexington
# Processing Record 17 of Set 4 | malartic
# Processing Record 18 of Set 4 | amuntai
# Processing Record 19 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 4 | esmeraldas
# Processing Record 21 of Set 4 | morro bay
# Processing Record 22 of Set 4 | santa cruz del sur
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | tocopilla
# Processing Record 25 of Set 4 | qui nhon
# Processing Record 26 of Set 4 | naze
# Processing Record 27 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | codrington
# Processing Record 29 of Set 4 | antsohihy
# Processing Record 30 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 4 | sapernyy
# Processing Record 32 of Set 4 | samarinda
# Processing Record 33 of Set 4 | verkhnyaya maksakovka
# Processing Record 34 of Set 4 | mana
# Processing Record 35 of Set 4 | warrnambool
# Processing Record 36 of Set 4 | warrington
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | hermanus
# Processing Record 39 of Set 4 | namibe
# Processing Record 40 of Set 4 | iquique
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | lasa
# Processing Record 43 of Set 4 | lokosovo
# Processing Record 44 of Set 4 | lazaro cardenas
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | itarema
# Processing Record 49 of Set 4 | bure
# Processing Record 50 of Set 4 | bat yam
# Processing Record 1 of Set 5 | yenagoa
# Processing Record 2 of Set 5 | zhumadian
# Processing Record 3 of Set 5 | bosaso
# Processing Record 4 of Set 5 | aswan
# Processing Record 5 of Set 5 | vorukh
# Processing Record 6 of Set 5 | grindavik
# Processing Record 7 of Set 5 | rio branco
# Processing Record 8 of Set 5 | nushki
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | tambura
# Processing Record 11 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 5 | deputatskiy
# Processing Record 13 of Set 5 | nicoya
# Processing Record 14 of Set 5 | meadow lake
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | zarasai
# Processing Record 17 of Set 5 | kununurra
# Processing Record 18 of Set 5 | lowestoft
# Processing Record 19 of Set 5 | tiarei
# Processing Record 20 of Set 5 | luderitz
# Processing Record 21 of Set 5 | sechura
# Processing Record 22 of Set 5 | lubao
# Processing Record 23 of Set 5 | sikea
# City not found. Skipping...
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | khurianwala
# City not found. Skipping...
# Processing Record 26 of Set 5 | pachperwa
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | hirara
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | fomboni
# Processing Record 31 of Set 5 | gat
# Processing Record 32 of Set 5 | grand-santi
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | dutlwe
# Processing Record 35 of Set 5 | parkes
# Processing Record 36 of Set 5 | igarka
# Processing Record 37 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 38 of Set 5 | hualmay
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | flin flon
# Processing Record 41 of Set 5 | bom jardim
# Processing Record 42 of Set 5 | chamrajnagar
# Processing Record 43 of Set 5 | maragogi
# Processing Record 44 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 5 | troitsko-pechorsk
# Processing Record 46 of Set 5 | paamiut
# Processing Record 47 of Set 5 | buala
# Processing Record 48 of Set 5 | sao filipe
# Processing Record 49 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 5 | shache
# Processing Record 1 of Set 6 | sudbury
# Processing Record 2 of Set 6 | maceio
# Processing Record 3 of Set 6 | marsa matruh
# Processing Record 4 of Set 6 | port alfred
# Processing Record 5 of Set 6 | beloha
# Processing Record 6 of Set 6 | kavieng
# Processing Record 7 of Set 6 | marsh harbour
# Processing Record 8 of Set 6 | alekseyevsk
# Processing Record 9 of Set 6 | richards bay
# Processing Record 10 of Set 6 | soyo
# Processing Record 11 of Set 6 | chontalpa
# Processing Record 12 of Set 6 | pacifica
# Processing Record 13 of Set 6 | cuorgne
# Processing Record 14 of Set 6 | paramonga
# Processing Record 15 of Set 6 | harindanga
# Processing Record 16 of Set 6 | bathsheba
# Processing Record 17 of Set 6 | ca mau
# Processing Record 18 of Set 6 | xining
# Processing Record 19 of Set 6 | mehamn
# Processing Record 20 of Set 6 | tahta
# Processing Record 21 of Set 6 | iwanai
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | mount isa
# Processing Record 24 of Set 6 | gudalur
# Processing Record 25 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 6 | lavrentiya
# Processing Record 27 of Set 6 | hasaki
# Processing Record 28 of Set 6 | ciudad guayana
# Processing Record 29 of Set 6 | mahalapye
# Processing Record 30 of Set 6 | altamira
# Processing Record 31 of Set 6 | krasnoselkup
# Processing Record 32 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | oulainen
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | praia da vitoria
# Processing Record 37 of Set 6 | panjab
# Processing Record 38 of Set 6 | posse
# Processing Record 39 of Set 6 | peniche
# Processing Record 40 of Set 6 | poli
# Processing Record 41 of Set 6 | galveston
# Processing Record 42 of Set 6 | ucluelet
# Processing Record 43 of Set 6 | kemijarvi
# Processing Record 44 of Set 6 | ransang
# Processing Record 45 of Set 6 | sosua
# Processing Record 46 of Set 6 | hofn
# Processing Record 47 of Set 6 | ilula
# Processing Record 48 of Set 6 | mahebourg
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | ozernovskiy
# Processing Record 1 of Set 7 | nanortalik
# Processing Record 2 of Set 7 | tonekabon
# Processing Record 3 of Set 7 | carire
# Processing Record 4 of Set 7 | olafsvik
# Processing Record 5 of Set 7 | benjamin constant
# Processing Record 6 of Set 7 | port hedland
# Processing Record 7 of Set 7 | port hardy
# Processing Record 8 of Set 7 | boquira
# Processing Record 9 of Set 7 | cabedelo
# Processing Record 10 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 7 | sangin
# Processing Record 12 of Set 7 | kampong chhnang
# Processing Record 13 of Set 7 | swift current
# Processing Record 14 of Set 7 | teya
# Processing Record 15 of Set 7 | innisfail
# Processing Record 16 of Set 7 | coquimbo
# Processing Record 17 of Set 7 | codajas
# Processing Record 18 of Set 7 | brae
# Processing Record 19 of Set 7 | fort nelson
# Processing Record 20 of Set 7 | srednekolymsk
# Processing Record 21 of Set 7 | carauari
# Processing Record 22 of Set 7 | shimabara
# Processing Record 23 of Set 7 | capitan bado
# Processing Record 24 of Set 7 | huarmey
# Processing Record 25 of Set 7 | la grande
# Processing Record 26 of Set 7 | palana
# Processing Record 27 of Set 7 | flinders
# Processing Record 28 of Set 7 | kieta
# Processing Record 29 of Set 7 | marsaxlokk
# Processing Record 30 of Set 7 | westport
# Processing Record 31 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 7 | oxbow
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | santa vitoria
# Processing Record 35 of Set 7 | bulgan
# Processing Record 36 of Set 7 | necochea
# Processing Record 37 of Set 7 | stornoway
# Processing Record 38 of Set 7 | mucurapo
# Processing Record 39 of Set 7 | boueni
# Processing Record 40 of Set 7 | antofagasta
# Processing Record 41 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 7 | nouakchott
# Processing Record 43 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 7 | aykhal
# Processing Record 45 of Set 7 | saint-nazaire
# Processing Record 46 of Set 7 | novo aripuana
# Processing Record 47 of Set 7 | tabou
# Processing Record 48 of Set 7 | mackenzie
# Processing Record 49 of Set 7 | freetown
# Processing Record 50 of Set 7 | elizabethton
# Processing Record 1 of Set 8 | saldanha
# Processing Record 2 of Set 8 | trapani
# Processing Record 3 of Set 8 | douglas
# Processing Record 4 of Set 8 | tynne
# Processing Record 5 of Set 8 | bani
# Processing Record 6 of Set 8 | tarakan
# Processing Record 7 of Set 8 | ginda
# Processing Record 8 of Set 8 | zhuhai
# Processing Record 9 of Set 8 | qaqortoq
# Processing Record 10 of Set 8 | russell
# Processing Record 11 of Set 8 | muros
# Processing Record 12 of Set 8 | port-gentil
# Processing Record 13 of Set 8 | ribeira grande
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | tarko-sale
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | los llanos de aridane
# Processing Record 18 of Set 8 | kachiry
# Processing Record 19 of Set 8 | duldurga
# Processing Record 20 of Set 8 | ambilobe
# Processing Record 21 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 8 | jeremie
# Processing Record 23 of Set 8 | arkhangelsk
# Processing Record 24 of Set 8 | noumea
# Processing Record 25 of Set 8 | pizarro
# Processing Record 26 of Set 8 | kungalv
# Processing Record 27 of Set 8 | barcelos
# Processing Record 28 of Set 8 | belaya gora
# Processing Record 29 of Set 8 | vila franca do campo
# Processing Record 30 of Set 8 | inhambane
# Processing Record 31 of Set 8 | yuxia
# Processing Record 32 of Set 8 | pathein
# Processing Record 33 of Set 8 | san cristobal
# Processing Record 34 of Set 8 | caucaia
# Processing Record 35 of Set 8 | ullal
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | aksu
# Processing Record 38 of Set 8 | antalaha
# Processing Record 39 of Set 8 | rosarito
# Processing Record 40 of Set 8 | rancho palos verdes
# Processing Record 41 of Set 8 | tuatapere
# Processing Record 42 of Set 8 | moree
# Processing Record 43 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 8 | liberal
# Processing Record 45 of Set 8 | usinsk
# Processing Record 46 of Set 8 | portel
# Processing Record 47 of Set 8 | valuyki
# Processing Record 48 of Set 8 | samarai
# Processing Record 49 of Set 8 | san rafael
# Processing Record 50 of Set 8 | healdsburg
# Processing Record 1 of Set 9 | kuala terengganu
# Processing Record 2 of Set 9 | whitianga
# Processing Record 3 of Set 9 | touros
# Processing Record 4 of Set 9 | nuuk
# Processing Record 5 of Set 9 | juba
# Processing Record 6 of Set 9 | la palma
# Processing Record 7 of Set 9 | sabha
# Processing Record 8 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 9 of Set 9 | lovozero
# Processing Record 10 of Set 9 | taoudenni
# Processing Record 11 of Set 9 | makakilo city
# Processing Record 12 of Set 9 | gornyak
# Processing Record 13 of Set 9 | gornopravdinsk
# Processing Record 14 of Set 9 | liverpool
# Processing Record 15 of Set 9 | mao
# Processing Record 16 of Set 9 | rivadavia
# Processing Record 17 of Set 9 | aransas pass
# Processing Record 18 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 9 | bethel
# Processing Record 20 of Set 9 | norman wells
# Processing Record 21 of Set 9 | walla walla
# Processing Record 22 of Set 9 | tooele
# Processing Record 23 of Set 9 | coihaique
# Processing Record 24 of Set 9 | marzuq
# Processing Record 25 of Set 9 | isla mujeres
# Processing Record 26 of Set 9 | kalmunai
# Processing Record 27 of Set 9 | constitucion
# Processing Record 28 of Set 9 | aloleng
# Processing Record 29 of Set 9 | weligama
# Processing Record 30 of Set 9 | guhagar
# Processing Record 31 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 9 | harper
# Processing Record 33 of Set 9 | asau
# Processing Record 34 of Set 9 | airai
# Processing Record 35 of Set 9 | port augusta
# Processing Record 36 of Set 9 | verkhnyaya inta
# Processing Record 37 of Set 9 | sijunjung
# Processing Record 38 of Set 9 | rio gallegos
# Processing Record 39 of Set 9 | chumikan
# Processing Record 40 of Set 9 | puerto madero
# Processing Record 41 of Set 9 | masuguru
# Processing Record 42 of Set 9 | jiayuguan
# Processing Record 43 of Set 9 | seredka
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | husavik
# Processing Record 46 of Set 9 | hervey bay
# Processing Record 47 of Set 9 | bolshoye selo
# Processing Record 48 of Set 9 | broken hill
# Processing Record 49 of Set 9 | saint-pierre
# Processing Record 50 of Set 9 | pirai do sul
# Processing Record 1 of Set 10 | bucyrus
# Processing Record 2 of Set 10 | srinivaspur
# Processing Record 3 of Set 10 | wheatley
# Processing Record 4 of Set 10 | ahipara
# Processing Record 5 of Set 10 | lapua
# Processing Record 6 of Set 10 | faanui
# Processing Record 7 of Set 10 | ilinskiy
# Processing Record 8 of Set 10 | arzgir
# Processing Record 9 of Set 10 | yerofey pavlovich
# Processing Record 10 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 10 | shimoda
# Processing Record 12 of Set 10 | silvassa
# Processing Record 13 of Set 10 | iralaya
# Processing Record 14 of Set 10 | bandarbeyla
# Processing Record 15 of Set 10 | cabo rojo
# Processing Record 16 of Set 10 | batemans bay
# Processing Record 17 of Set 10 | stokmarknes
# Processing Record 18 of Set 10 | payo
# Processing Record 19 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 10 | changji
# Processing Record 21 of Set 10 | burnie
# Processing Record 22 of Set 10 | dzhebariki-khaya
# Processing Record 23 of Set 10 | langsa
# Processing Record 24 of Set 10 | cuyo
# Processing Record 25 of Set 10 | kawai
# Processing Record 26 of Set 10 | pavino
# Processing Record 27 of Set 10 | black diamond
# Processing Record 28 of Set 10 | niquero
# Processing Record 29 of Set 10 | saint-augustin
# Processing Record 30 of Set 10 | la romana
# Processing Record 31 of Set 10 | nyurba
# Processing Record 32 of Set 10 | dunedin
# Processing Record 33 of Set 10 | cody
# Processing Record 34 of Set 10 | oktyabrskiy
# Processing Record 35 of Set 10 | elko
# Processing Record 36 of Set 10 | shubarshi
# Processing Record 37 of Set 10 | maraa
# Processing Record 38 of Set 10 | murray bridge
# Processing Record 39 of Set 10 | garm
# City not found. Skipping...
# Processing Record 40 of Set 10 | svetlyy
# Processing Record 41 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 42 of Set 10 | lorengau
# Processing Record 43 of Set 10 | portland
# Processing Record 44 of Set 10 | jumla
# Processing Record 45 of Set 10 | alta floresta
# Processing Record 46 of Set 10 | teahupoo
# Processing Record 47 of Set 10 | barcelona
# Processing Record 48 of Set 10 | dalhousie
# Processing Record 49 of Set 10 | cervo
# Processing Record 50 of Set 10 | pokaran
# Processing Record 1 of Set 11 | begoro
# Processing Record 2 of Set 11 | kushiro
# Processing Record 3 of Set 11 | fairbanks
# Processing Record 4 of Set 11 | lancaster
# Processing Record 5 of Set 11 | kirakira
# Processing Record 6 of Set 11 | kyra
# Processing Record 7 of Set 11 | todos santos
# Processing Record 8 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 11 | misratah
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | granada
# Processing Record 12 of Set 11 | namatanai
# Processing Record 13 of Set 11 | sarangani
# Processing Record 14 of Set 11 | taft
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | honiara
# Processing Record 17 of Set 11 | serenje
# Processing Record 18 of Set 11 | constantine
# Processing Record 19 of Set 11 | leh
# Processing Record 20 of Set 11 | palmer
# Processing Record 21 of Set 11 | nome
# Processing Record 22 of Set 11 | pozhva
# Processing Record 23 of Set 11 | camana
# Processing Record 24 of Set 11 | port hawkesbury
# Processing Record 25 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 26 of Set 11 | kasama
# Processing Record 27 of Set 11 | bowen
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | beyneu
# Processing Record 30 of Set 11 | paragominas
# Processing Record 31 of Set 11 | boende
# Processing Record 32 of Set 11 | hamilton
# Processing Record 33 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 11 | ust-barguzin
# Processing Record 35 of Set 11 | ciudad bolivar
# Processing Record 36 of Set 11 | victoria
# Processing Record 37 of Set 11 | campbell river
# Processing Record 38 of Set 11 | bati
# Processing Record 39 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 11 | marechal candido rondon
# Processing Record 41 of Set 11 | sao joao da barra
# Processing Record 42 of Set 11 | green river
# Processing Record 43 of Set 11 | henties bay
# Processing Record 44 of Set 11 | katsuura
# Processing Record 45 of Set 11 | sioux lookout
# Processing Record 46 of Set 11 | uchiza
# Processing Record 47 of Set 11 | waipawa
# Processing Record 48 of Set 11 | adre
# Processing Record 49 of Set 11 | dalvik
# Processing Record 50 of Set 11 | kortkeros
# Processing Record 1 of Set 12 | rundu
# Processing Record 2 of Set 12 | hit
# Processing Record 3 of Set 12 | tukrah
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | erzin
# Processing Record 6 of Set 12 | kenitra
# Processing Record 7 of Set 12 | fort-shevchenko
# Processing Record 8 of Set 12 | indiana
# Processing Record 9 of Set 12 | yangambi
# Processing Record 10 of Set 12 | irbil
# Processing Record 11 of Set 12 | diamantino
# Processing Record 12 of Set 12 | sulangan
# Processing Record 13 of Set 12 | marawi
# Processing Record 14 of Set 12 | terrace bay
# Processing Record 15 of Set 12 | zhicheng
# Processing Record 16 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 12 | mount pleasant
# Processing Record 18 of Set 12 | valparaiso
# Processing Record 19 of Set 12 | porto nacional
# Processing Record 20 of Set 12 | catia la mar
# Processing Record 21 of Set 12 | veraval
# Processing Record 22 of Set 12 | guanica
# Processing Record 23 of Set 12 | stykkisholmur
# Processing Record 24 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 12 | polewali
# Processing Record 26 of Set 12 | saint-louis
# Processing Record 27 of Set 12 | kurilsk
# Processing Record 28 of Set 12 | ormara
# Processing Record 29 of Set 12 | bubaque
# Processing Record 30 of Set 12 | kalabo
# Processing Record 31 of Set 12 | puerto el triunfo
# Processing Record 32 of Set 12 | bay roberts
# Processing Record 33 of Set 12 | linjiang
# Processing Record 34 of Set 12 | la rioja
# Processing Record 35 of Set 12 | bac lieu
# Processing Record 36 of Set 12 | yeppoon
# Processing Record 37 of Set 12 | qinzhou
# Processing Record 38 of Set 12 | vardo
# Processing Record 39 of Set 12 | shepsi
# Processing Record 40 of Set 12 | ville-marie
# Processing Record 41 of Set 12 | cojumatlan
# City not found. Skipping...
# Processing Record 42 of Set 12 | awbari
# Processing Record 43 of Set 12 | cayenne
# Processing Record 44 of Set 12 | butembo
# Processing Record 45 of Set 12 | penzance
# Processing Record 46 of Set 12 | orocue
# Processing Record 47 of Set 12 | salekhard
# Processing Record 48 of Set 12 | grand-lahou
# Processing Record 49 of Set 12 | pangnirtung
# Processing Record 50 of Set 12 | avera
# Processing Record 1 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 13 | mahanoro
# Processing Record 3 of Set 13 | miramar
# Processing Record 4 of Set 13 | umarkot
# Processing Record 5 of Set 13 | havoysund
# Processing Record 6 of Set 13 | ende
# Processing Record 7 of Set 13 | quang ngai
# Processing Record 8 of Set 13 | pandan
# Processing Record 9 of Set 13 | filingue
# Processing Record 10 of Set 13 | le moule
# Processing Record 11 of Set 13 | sobolevo
# Processing Record 12 of Set 13 | nioro
# Processing Record 13 of Set 13 | fairlie
# Processing Record 14 of Set 13 | kihei
# Processing Record 15 of Set 13 | adrar
# Processing Record 16 of Set 13 | kazanlak
# Processing Record 17 of Set 13 | ranong
# Processing Record 18 of Set 13 | chimichagua
# Processing Record 19 of Set 13 | huambo
# Processing Record 20 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 13 | suntar
# Processing Record 22 of Set 13 | angoche
# Processing Record 23 of Set 13 | timrat
# Processing Record 24 of Set 13 | kaliua
# Processing Record 25 of Set 13 | lima
# Processing Record 26 of Set 13 | contamana
# Processing Record 27 of Set 13 | peleduy
# Processing Record 28 of Set 13 | clyde
# Processing Record 29 of Set 13 | tres lagoas
# Processing Record 30 of Set 13 | laguna
# Processing Record 31 of Set 13 | nelson bay
# Processing Record 32 of Set 13 | urumqi
# Processing Record 33 of Set 13 | apen
# Processing Record 34 of Set 13 | goderich
# Processing Record 35 of Set 13 | burns lake
# Processing Record 36 of Set 13 | dhidhdhoo
# Processing Record 37 of Set 13 | shihezi
# Processing Record 38 of Set 13 | mbandaka
# Processing Record 39 of Set 13 | butte
# Processing Record 40 of Set 13 | anuradhapura
# Processing Record 41 of Set 13 | verkh-usugli
# Processing Record 42 of Set 13 | tecoanapa
# Processing Record 43 of Set 13 | hovd
# Processing Record 44 of Set 13 | porto seguro
# Processing Record 45 of Set 13 | mabaruma
# Processing Record 46 of Set 13 | rodrigues alves
# Processing Record 47 of Set 13 | kushikino
# Processing Record 48 of Set 13 | spas
# Processing Record 49 of Set 13 | osmena
# Processing Record 50 of Set 13 | les escoumins
# Processing Record 1 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 14 | calama
# Processing Record 3 of Set 14 | te anau
# Processing Record 4 of Set 14 | gravdal
# Processing Record 5 of Set 14 | dangriga
# Processing Record 6 of Set 14 | ugoofaaru
# Processing Record 7 of Set 14 | svetlogorsk
# Processing Record 8 of Set 14 | abu samrah
# Processing Record 9 of Set 14 | bannu
# Processing Record 10 of Set 14 | caravelas
# Processing Record 11 of Set 14 | mataram
# Processing Record 12 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 13 of Set 14 | haines junction
# Processing Record 14 of Set 14 | saint-jean-port-joli
# Processing Record 15 of Set 14 | glogow
# Processing Record 16 of Set 14 | antas
# Processing Record 17 of Set 14 | hereford
# Processing Record 18 of Set 14 | gamboula
# Processing Record 19 of Set 14 | linqing
# Processing Record 20 of Set 14 | manzhouli
# Processing Record 21 of Set 14 | clyde river
# Processing Record 22 of Set 14 | spokane
# Processing Record 23 of Set 14 | nizhniy kislyay
# Processing Record 24 of Set 14 | donskoye
# Processing Record 25 of Set 14 | pueblo
# Processing Record 26 of Set 14 | ngama
# Processing Record 27 of Set 14 | hambantota
# Processing Record 28 of Set 14 | sao felix do xingu
# Processing Record 29 of Set 14 | dingle
# Processing Record 30 of Set 14 | pontian kecil
# Processing Record 31 of Set 14 | atar
# Processing Record 32 of Set 14 | massakory
# Processing Record 33 of Set 14 | hay river
# Processing Record 34 of Set 14 | zemaiciu naumiestis
# Processing Record 35 of Set 14 | khorinsk
# Processing Record 36 of Set 14 | filadelfia
# Processing Record 37 of Set 14 | saint-francois
# Processing Record 38 of Set 14 | banda aceh
# Processing Record 39 of Set 14 | wukari
# Processing Record 40 of Set 14 | labuhan
# Processing Record 41 of Set 14 | ishim
# Processing Record 42 of Set 14 | adilabad
# Processing Record 43 of Set 14 | hope
# Processing Record 44 of Set 14 | los lunas
# Processing Record 45 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 14 | quatre cocos
# Processing Record 47 of Set 14 | anahuac
# Processing Record 48 of Set 14 | pasighat
# Processing Record 49 of Set 14 | kuliyapitiya
# Processing Record 50 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 15 | phalaborwa
# Processing Record 3 of Set 15 | kamenka
# Processing Record 4 of Set 15 | jambi
# Processing Record 5 of Set 15 | opuwo
# Processing Record 6 of Set 15 | rorvik
# Processing Record 7 of Set 15 | along
# Processing Record 8 of Set 15 | hue
# Processing Record 9 of Set 15 | jining
# Processing Record 10 of Set 15 | noda
# Processing Record 11 of Set 15 | bundaberg
# Processing Record 12 of Set 15 | hobyo
# Processing Record 13 of Set 15 | orlik
# Processing Record 14 of Set 15 | tokur
# Processing Record 15 of Set 15 | menongue
# Processing Record 16 of Set 15 | carutapera
# Processing Record 17 of Set 15 | half moon bay
# Processing Record 18 of Set 15 | rantepao
# Processing Record 19 of Set 15 | jimenez
# Processing Record 20 of Set 15 | sakakah
# Processing Record 21 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 15 | ridgecrest
# Processing Record 23 of Set 15 | mnogovershinnyy
# Processing Record 24 of Set 15 | mitsamiouli
# Processing Record 25 of Set 15 | broadstairs
# Processing Record 26 of Set 15 | broome
# Processing Record 27 of Set 15 | fort payne
# Processing Record 28 of Set 15 | conde
# Processing Record 29 of Set 15 | belmonte
# Processing Record 30 of Set 15 | rio hondo
# Processing Record 31 of Set 15 | kargopol
# Processing Record 32 of Set 15 | dongsheng
# Processing Record 33 of Set 15 | diego de almagro
# Processing Record 34 of Set 15 | nouadhibou
# Processing Record 35 of Set 15 | bhandara
# Processing Record 36 of Set 15 | juan aldama
# Processing Record 37 of Set 15 | baghdad
# Processing Record 38 of Set 15 | saquena
# Processing Record 39 of Set 15 | zyryanka
# Processing Record 40 of Set 15 | luganville
# Processing Record 41 of Set 15 | puerto escondido
# Processing Record 42 of Set 15 | uyuni
# Processing Record 43 of Set 15 | karratha
# Processing Record 44 of Set 15 | mandalgarh
# Processing Record 45 of Set 15 | pareora
# Processing Record 46 of Set 15 | ensenada
# Processing Record 47 of Set 15 | kantabanji
# Processing Record 48 of Set 15 | berbera
# Processing Record 49 of Set 15 | santa cruz de tenerife
# Processing Record 50 of Set 15 | lyubytino
# Processing Record 1 of Set 16 | santa ana
# Processing Record 2 of Set 16 | kiama
# Processing Record 3 of Set 16 | kingaroy
# Processing Record 4 of Set 16 | wanxian
# Processing Record 5 of Set 16 | maniitsoq
# Processing Record 6 of Set 16 | turukhansk
# Processing Record 7 of Set 16 | taksimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Salamiyah  35.0113   37.0532     58.42        34          18        5.12
# 1   Chokurdakh  70.6333  147.9167    -10.41        97          83        8.70
# 2     Zhigansk  66.7697  123.3711     -3.10        93          85       14.83
# 3  Verkhoyansk  67.5447  133.3850     -6.29        99          96        1.21
# 4       Viedma -40.8135  -62.9967     61.48        35          30       10.20
# 5        Pevek  69.7008  170.3133    -12.50        94          35        4.70
# 6         Ocos  14.5094  -92.1933     87.98        65           1        9.89
# 7      Rikitea -23.1203 -134.9692     78.17        61           5       11.34
# 8    Kavaratti  10.5669   72.6420     81.66        76          50        5.14
# 9       Trojes  41.7560   19.9620     41.49        89         100        4.21
#
#   Current Description Country
# 0          few clouds      SY
# 1       broken clouds      RU
# 2     overcast clouds      RU
# 3     overcast clouds      RU
# 4    scattered clouds      AR
# 5    scattered clouds      RU
# 6           clear sky      GT
# 7           clear sky      PF
# 8    scattered clouds      IN
# 9     overcast clouds      AL

# %%
new_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_city_data_df]

# %%
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Salamiyah      SY  35.0113   37.0532     58.42        34          18
# 1     Chokurdakh      RU  70.6333  147.9167    -10.41        97          83
# 2       Zhigansk      RU  66.7697  123.3711     -3.10        93          85
# 3    Verkhoyansk      RU  67.5447  133.3850     -6.29        99          96
# 4         Viedma      AR -40.8135  -62.9967     61.48        35          30
# ..           ...     ...      ...       ...       ...       ...         ...
# 702     Kingaroy      AU -26.5333  151.8333     73.83        59           0
# 703      Wanxian      CN  30.8039  108.3897     56.32        94          99
# 704    Maniitsoq      GL  65.4167  -52.9000     26.46        78          33
# 705   Turukhansk      RU  65.8167   87.9833     24.08        88         100
# 706      Taksimo      RU  56.3444  114.8794     11.97        87         100
#
#      Wind Speed Current Description
# 0          5.12          few clouds
# 1          8.70       broken clouds
# 2         14.83     overcast clouds
# 3          1.21     overcast clouds
# 4         10.20    scattered clouds
# ..          ...                 ...
# 702        3.78          light rain
# 703        3.89     overcast clouds
# 704        2.42    scattered clouds
# 705       19.35     overcast clouds
# 706        4.52     overcast clouds
#
# [707 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
